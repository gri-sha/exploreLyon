# %%
import pandas as pd
from pathlib import Path
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from utils import *

# %%
df = pd.read_pickle("data/flickr_data_with_features.pkl")

with open("data/tags_to_delete.txt", "r") as f:
    tags_to_delete = set(line.strip() for line in f)

# %%
YEAR = 2016
N_CLUSTERS = 240
ONLY_SIMILAR_YEARS = True

sample = None
if YEAR == "all":
    sample = df.copy()
else:
    sample = df[df["date_taken"].dt.year == YEAR].copy()

if ONLY_SIMILAR_YEARS:
    sample = sample[sample["similar_year"] == 1]

coords = sample[["lat", "long"]].values

lat_rad = np.radians(coords[:, 0])
long_rad = np.radians(coords[:, 1])
x = np.cos(lat_rad) * np.cos(long_rad)
y = np.cos(lat_rad) * np.sin(long_rad)
z = np.sin(lat_rad)
coords_cartesian = np.column_stack([x, y, z])

clustering = AgglomerativeClustering(
    n_clusters=N_CLUSTERS,
    metric='euclidean',
    linkage='ward'
)
sample["cluster"] = clustering.fit_predict(coords_cartesian)

n_clusters = len(set(sample["cluster"]))

print(f"Number of clusters: {n_clusters}")
print(f"\nCluster distribution:")
print(sample["cluster"].value_counts().sort_index())
# Out:
# Number of clusters: 240
#
# Cluster distribution:
# cluster
# 0       19
# 1      500
# 2       12
# 3       77
# 4       59
#       ...
# 235     19
# 236     15
# 237      5
# 238     65
# 239      1
# Name: count, Length: 240, dtype: int64

# %%
N_TOP_TAGS = 5

cluster_top_tags = get_cluster_top_tags(sample, tags_to_delete, N_TOP_TAGS)
print(f"\nTop {N_TOP_TAGS} tags per cluster:")
for cluster_id in sorted(cluster_top_tags.keys()):
    print(f"Cluster {cluster_id}: {', '.join(cluster_top_tags[cluster_id])}")
# Out:
# Top 5 tags per cluster:
# Cluster 0: streetphotography, noiretblanc, blackandwhite, streetart, pavement
# Cluster 1: rhône, fourvière, square, basilique, nuit
# Cluster 2: las, streetart, paper, wheatpaste, lasgatas
# Cluster 3: adcet, tect, sanscontact»nfcollectivités, territorialeslyonsanscontactnfccollectivités, territoriales
# Cluster 4: rhone, alpes, tige, fleur, flowers
# Cluster 5: square, clarendon, valencia
# Cluster 6: rhône, light, night, nuit, rhone
# Cluster 7: streetart, wheatpaste, wheatpaper, paper, 5dmkiii
# Cluster 8: fontaine, placedesjacobins, fetedeslumieres, night, jacobins
# Cluster 9: basket, petits, rois, scb, tournoi
# Cluster 10: croixrousse, streetart, origo, 4ème, restaurant
# Cluster 11: square, mural, mur, peint, trompeloeil
# Cluster 12: square, clarendon, perpetua, gingham
# Cluster 13: skateboarding, skateboard, street, skate, skatepark
# Cluster 14: miniature, rhône, nikkor, musée, 18105
# Cluster 15: gare, paul, saint, fêtedeslumières, 5ème
# Cluster 16: ldollfestival, ldoll2016, ldoll6, rencontre, résines
# Cluster 17: croixrousse, streetart, paper, wheatpaste, wheatpaper
# Cluster 18: affiche, charbonnièreslesbains, rallyelyoncharbonnièresrhône2016, nature, aquarelle
# Cluster 19: rhône, pont, water, reflection, architecture
# Cluster 20: croixrousse, jardin, rosa, mir, square
# Cluster 21: streetart, croixrousse, concert, musique, lestantansflingueurs
# Cluster 22: croixrousse, quaidesaone, eyefi, rhone, traboules
# Cluster 23: theatre, antique, 8, 8decembre, decembre
# Cluster 24: hôteldieu, travaux, 20152017, filoer, variotessartfe1635mmf4zaoss
# Cluster 25: nuit, hbarrison, harveybarrison, rhone, lumières
# Cluster 26: conference, iot, citéinternationaledelyon, internetdesobjets, objetsconnectés
# Cluster 27: omdem5markii, vscofilm, panasonic25mmf14, mft, omd
# Cluster 28: sncf, publictransport, train, gare, station
# Cluster 29: guerrede1418, ww1, 69rhone, warmemorial, monumentauxmorts
# Cluster 30: pont, poselongue, urban, architecture, nuit
# Cluster 31: lcf, lcf2016, lcflyon, lcflyon2016, lamborghini
# Cluster 32: supermimil, fdl, ptdo, parcdelatêtedor, square
# Cluster 33: musician, music, concert, nikkor, musique
# Cluster 34: lac, animaux, miribel, oiseau, étang
# Cluster 35: parapluie, street, homme, pluie, rain
# Cluster 36: square, lark
# Cluster 37: square, mural, mur, peint, trompeloeil
# Cluster 38: night, nuit, passerelle, nikoncoolpixp7100, pont
# Cluster 39: openapnéelyon2016, facebook, rhône, harveybarrison, hbarrison
# Cluster 40: mac, fdl, supermimil, square, clarendon
# Cluster 41: cimitièreloyasse, cimitièredeloyasse, cimetièredeloyasse, blackandwhite, noiretblanc
# Cluster 42: sonic, concert, show, peterkernel, troyvonbalthazar
# Cluster 43: miribel, ain, animaux, faune, jonage
# Cluster 44: saône, nuit, fêtedeslumières, vieuxlyon, pont
# Cluster 45: ol, décinescharpieu, stade, foot, lumière
# Cluster 46: square, camion, truck, frenchtruck, années90
# Cluster 47: parc, parilly, 7dwf, microfourthirds, micro43
# Cluster 48: concert, show, marché, gare, grand
# Cluster 49: croixrousse, streetart, square, paper, wheatpaste
# Cluster 50: brocante, vente, femme, foule, objet
# Cluster 51: demeureduchaos, thierryehrmann, abodeofchaos, chaos, sculpture
# Cluster 52: girl, femme, woman, fille, feminine
# Cluster 53: hallesdelyon, rhône, immeuble, building, blue
# Cluster 54: square
# Cluster 55: night, fourvière, saône, nuit, eyefi
# Cluster 56: harveybarrison, hbarrison, perrache, rhone, square
# Cluster 57: square
# Cluster 58: square, rhône, streetphotography, cordeliers, 69002
# Cluster 59: square, aquarelle, parc, arbres, nature
# Cluster 60: poppy, poppies, splash, bron, coquelicot
# Cluster 61: graffiti, 4ème, collège, maurice, sève
# Cluster 62: eyefi, fdl, n1, supermimil, rhône
# Cluster 63: hbarrison, harveybarrison, lyon2earrondissement, rhône, architecture
# Cluster 64: rhône, muséedesbeauxarts, exposition, derembrandtauselfie, fêtedeslumières2016
# Cluster 65: coiffeur, barbier, harveybarrison, hbarrison, blackandwhite
# Cluster 66: muséedesconfluences, architecture, musée, confluence, square
# Cluster 67: parcdelatêtedor, sortiephotodu7052016, nature, horizontal, fra
# Cluster 68: saintefoylèslyon
# Cluster 69: industriel, métal, rotonde, sncf, rail
# Cluster 70: square, clarendon
# Cluster 71:
# Cluster 72: tgv, carréfamille
# Cluster 73: croixrousse, zombiewalk, eos6d, patman, photomobile
# Cluster 74: 1d, judo, gerland, judoka, sony
# Cluster 75: citéinternationale, chocolat, défilé, places, salonduchocolat
# Cluster 76: river, rhone, cruise, ship, boat
# Cluster 77: balcon, macro, extensionring, makinon, architecture
# Cluster 78: publictransport, tcl, architecture, lyon3earrondissement, archivesmunicipales
# Cluster 79: nuit, skate, skateboard, skateboarding, skatepark
# Cluster 80: oewg, street, sport, skateboarding, skatepark
# Cluster 81: hôtelariana, hôtel, basket, petits, rois
# Cluster 82: confluence, rhône, villes, villages, tourisme
# Cluster 83: square, croixrousse, streetart, paper, wheatpaste
# Cluster 84: rhône, nuit, saône, night, architecture
# Cluster 85: pont, rhône, bridge, architecture, pontraymondbarre
# Cluster 86: parc, nature, fleur, plante, têtedor
# Cluster 87: vocaloid, hatsunemiku, kagaminerin, cosplay, square
# Cluster 88: couzon, d7000, tamron, 1750, night
# Cluster 89: vaulxenvelin, transport, dxo, noirblanc, iphone
# Cluster 90: square, perpetua, rise, amaro, hudson
# Cluster 91: de, goal, stadium, euro, soccer
# Cluster 92: streetart, door, doors, porte, paper
# Cluster 93: confluence, fdl, supermimil, confluences, musée
# Cluster 94: square, tassinlademilune, blue, sky, cloud
# Cluster 95: streetart, street, paper, wheatpaste, wheatpaper
# Cluster 96: canoneos550d, tamronsp60mmf2macrodiii, macro, nature, croixrousse
# Cluster 97: parc, parcdelatêtedor, fdl, pont, supermimil
# Cluster 98: tassin, tassinlademilune, red, car, vw
# Cluster 99: square, harveybarrison, hbarrison, clarendon, rhone
# Cluster 100: parcdelatêtedor, statue, tree, arbre, bronze
# Cluster 101: river, rhônerivercruise, streetart, basilicanotredamedefourviere, décembre
# Cluster 102: vieuxlyon, street, fourvière, streetart, rhône
# Cluster 103: november, ruejoliotcurie, square, animals, cat
# Cluster 104: rugby, sport, rhônesportif, canonef70200mmf4lusm, pluie
# Cluster 105: architecture, urban, pentax, pentaxk3ii, rhône
# Cluster 106: parcdelatêtedor, paris, novembre, jour, 3
# Cluster 107: cosplay, epoquauto, salon, car, exposition
# Cluster 108: euro2016, belgiumvsitaly
# Cluster 109: extérieur, sport, soleil, skateboarding, skatepark
# Cluster 110: croixrousse, streetart, places, walk, zombie
# Cluster 111: streetart, croixrousse, paper, wheatpaste, wheatpaper
# Cluster 112: square, perpetua, foursquare:venue=4e0462c82271233b767cec75, xproii, amaro
# Cluster 113: train, extérieur, railway, gare, de
# Cluster 114: croixrousse, streetart, installation, paper, wheatpaste
# Cluster 115: enfant, cigne, lamulatière, rhônerivercruise, rue
# Cluster 116: prison, resistance, street, 50mm, f14
# Cluster 117: rhône, longexposure, urban, night, nightlights
# Cluster 118: fantôme, ghost, peluche, ciseaux, lune
# Cluster 119: nuit, tamron, saône, streetart, croixrousse
# Cluster 120: river, water, soleil, eau, coucher
# Cluster 121: samyang12mmf2ncs, μ43, olympus, em10
# Cluster 122: 35mm, rhône, f18, saone, 3518
# Cluster 123: transbordeur, concert, metal, auvergnerhã´nealpes, baseproduction
# Cluster 124: labbaye, de, collonges, paul, bocuse
# Cluster 125: square, sierra, ludwig
# Cluster 126: lac, miribel, ain, animaux, faune
# Cluster 127: saintdidieraumontdor, landscape, house, evening, cityscape
# Cluster 128: baak, motorcycle, moto, cafe, racer
# Cluster 129: étudiante, résidence, 9, logementétudiant, résidenceétudiante
# Cluster 130: boallert, emile, trx, moto, yamaha
# Cluster 131: square
# Cluster 132: confluence, rhone, olympus, em5, rhône
# Cluster 133:
# Cluster 134: boardgame, j2s, croixrousse, streetart, soleil
# Cluster 135: bellecour, places, place, placebellecour, amaitsuki
# Cluster 136: vieuxlyon, streetart, square, architecture, urban
# Cluster 137: river, sky, charlessayerphotographies, photographer, thephotographyblog
# Cluster 138: square, têtedor, flamenco, mariagasca, automne
# Cluster 139:
# Cluster 140: guerrede1418, ww1, 69rhone, warmemorial, monumentauxmorts
# Cluster 141:
# Cluster 142: square, auvergnerhonealpes, rhone, architecture, formatportrait
# Cluster 143: eyefi, streetart, hbarrison, harveybarrison, wall
# Cluster 144: euro2016, porwal, por, wal
# Cluster 145: sncf, train, de, railway, locomotive
# Cluster 146: marcdelpiano, blackandwhite, noiretblanc, bw, nb
# Cluster 147: square, juno
# Cluster 148: square
# Cluster 149: square, prostitute, prostitution, van, bmc
# Cluster 150: fêtedeslumières, nuit, fdl, n1, supermimil
# Cluster 151: architecture, confluence, orange, urban, batiment
# Cluster 152: street, car, photographer, crossingroads, canonef2880mm13556
# Cluster 153: architecture, longexposure, urban, night, landscape
# Cluster 154: square, charmes
# Cluster 155: rhône, 法国, pont, supermimil, bridge
# Cluster 156: square
# Cluster 157:
# Cluster 158: mural, mur, peint, trompeloeil, fresque
# Cluster 159: aqueduc, chaponost
# Cluster 160: square, strret, hôpital, st, jean
# Cluster 161: m16, asvelrugby, 20152016, case, rugby
# Cluster 162: mars, festival, cosplay, 05, foy
# Cluster 163: rhone, river, amacello, apt, ama
# Cluster 164: miribel, ain, animaux, faune, jonage
# Cluster 165: 20162017, bordeaux, fb, j15, lou
# Cluster 166: square, foursquare:venue=52347c1b11d2334efcf8d1ba, clarendon, juno, hefe
# Cluster 167: d7200, sigma, sigmaart, art, 1835
# Cluster 168: square
# Cluster 169: music, metal, concert, metalmusic, overkill
# Cluster 170: longboard, arbre, vitesse, nature, vert
# Cluster 171: adcet, tect, collectivitésterritoriales, sanscontact»nfcollectivités, territoriales
# Cluster 172: confluence, rhône, square, villes, villages
# Cluster 173: charbon, bois, vieuxlyon, coal, wood
# Cluster 174: brotteaux, architecture, rhône, lyon6ème, plm
# Cluster 175: lov, intérieur, travaux
# Cluster 176: bron, square, tramway, clarendon, foursquare:venue=4ca4d703554b236a64af3248
# Cluster 177: saintfortunat, home, wall, street, summer
# Cluster 178: square, foursquare:venue=5002c16ce4b000090f9470ec, amaro, perpetua, clarendon
# Cluster 179: square, clarendon
# Cluster 180: confluence, centrecommercial, pointofview, sky, promenade
# Cluster 181: square
# Cluster 182: d7000, 50, 18, af, sitting
# Cluster 183:
# Cluster 184: square, architecture, blackwhite, lyonconfluence
# Cluster 185: japan, touch, convention, festival, decembre
# Cluster 186: croixrousse, places, walk, zombie, rhone
# Cluster 187: square, sncf, train, bahn, ter
# Cluster 188: rhône, square, passerelle, fdl, supermimil
# Cluster 189: eljlyon, campusdeladoua, laura, lyon1, lapref
# Cluster 190: cathédrale, rhône, fêtedeslumières, saone, d5300
# Cluster 191: travelingtheworld, 法國, 里昂
# Cluster 192: market, streetphotography, rhône, marché, urbanphotography
# Cluster 193: cadre, photoancienne, mariage, 1954, coffret
# Cluster 194: square, street, light, shadow, sky
# Cluster 195: basket, petits, rois, scb, tournoi
# Cluster 196: landscape, eau, pentax, hiver, rhône
# Cluster 197: canonef24105mmf4lisusm, canoneos7dmkii, miniatures, places, bellecour
# Cluster 198: square, photographieurbaine, urbanphotography, vaise, 69009
# Cluster 199: arielvillegas, filmphotography, summarit3525, blackandwhite, kodak
# Cluster 200: square
# Cluster 201: drive, voiture, 24mm, nikkor, ai
# Cluster 202: croixrousse, streetart, paper, wheatpaste, wheatpaper
# Cluster 203: parcdelatêtedor, square, naturaleza, nature, natureza
# Cluster 204: streetphotography, rhône, urbanphotography, têtedor, 69006
# Cluster 205: miribel, jonage, lac, oiseau, ornithologie
# Cluster 206: river, rhone, harveybarrison, hbarrison, 35mm
# Cluster 207: rhone, olympus, confluence, em5, lasucriere
# Cluster 208: vaulxenvelin, brocante, rhone, marchéauxpucesducanal, cadenas
# Cluster 209: rhône, chaponost, architecture, cabanon, pierre
# Cluster 210: square
# Cluster 211: architecture, 35mm, pentax, iso400, dxo
# Cluster 212: square
# Cluster 213: photographiederue, streetphotography, photographieurbaine, urbanphotography, ruegervaisbussière
# Cluster 214: rhônerivercruise, jacquesmeynierdemalviala, pizza, lechâteaudelaraignée, street
# Cluster 215:
# Cluster 216: rhone, square
# Cluster 217:
# Cluster 218: resiste, square, 1001buildings, rhône, augustus
# Cluster 219:
# Cluster 220: square, fra, geo:lat=4577018070, geo:lon=486236378, geotagged
# Cluster 221:
# Cluster 222: square, nashville, clarendon, hefe, juno
# Cluster 223: iron, fer, d3300, rust, rouille
# Cluster 224: boardgame, j2s
# Cluster 225: saab, 900, turbo, 16valve, spg
# Cluster 226: landscape, paysage, urban, hiver, rhône
# Cluster 227:
# Cluster 228: square, perpetua, rise, hudson, clarendon
# Cluster 229: square, ludwig
# Cluster 230: square
# Cluster 231: square
# Cluster 232:
# Cluster 233: water, animal, eau, pentax, printemps
# Cluster 234: rhone
# Cluster 235: square, river, mist, sunrise, bordsdesaône
# Cluster 236: river, wildlife, streetart, rhônerivercruise, soleil
# Cluster 237: provence, cruise, ship, rhônerivercruise, saintfons
# Cluster 238: architecture, urban, tower, tour, pentax
# Cluster 239: lac, baignade, miribel

# %%
save_dir = Path("./data/agglomerative/")
save_dir.mkdir(parents=True, exist_ok=True)
create_cluster_map(sample=sample, cluster_top_tags=cluster_top_tags, year=YEAR, show_noise=False, show_points=False, save_dir=save_dir)
# Out:
# Cluster map saved to data/agglomerative/2016_clusters_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa4487ca0b62f4fe1a0ba1d66d121f51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa4487ca0b62f4fe1a0ba1d66d121f51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa4487ca0b62f4fe1a0ba1d66d121f51 = L.map(
#                 &quot;map_aa4487ca0b62f4fe1a0ba1d66d121f51&quot;,
#                 {
#                     center: [45.7615, 4.83],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcfd842369bc85e1babccddf8cef8464 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcfd842369bc85e1babccddf8cef8464.addTo(map_aa4487ca0b62f4fe1a0ba1d66d121f51);
#
#
#     var color_map_492be1cd63c18589e72e983fdc8498f6 = {};
#
#
#     color_map_492be1cd63c18589e72e983fdc8498f6.color = d3.scale.threshold()
#               .domain([0.0, 0.4789579158316633, 0.9579158316633266, 1.43687374749499, 1.9158316633266532, 2.3947895791583167, 2.87374749498998, 3.352705410821643, 3.8316633266533064, 4.31062124248497, 4.789579158316633, 5.268537074148297, 5.74749498997996, 6.226452905811623, 6.705410821643286, 7.18436873747495, 7.663326653306613, 8.142284569138276, 8.62124248496994, 9.100200400801603, 9.579158316633267, 10.05811623246493, 10.537074148296593, 11.016032064128256, 11.49498997995992, 11.973947895791584, 12.452905811623246, 12.93186372745491, 13.410821643286573, 13.889779559118237, 14.3687374749499, 14.847695390781563, 15.326653306613226, 15.80561122244489, 16.284569138276552, 16.763527054108216, 17.24248496993988, 17.721442885771545, 18.200400801603205, 18.67935871743487, 19.158316633266534, 19.637274549098198, 20.11623246492986, 20.595190380761522, 21.074148296593187, 21.55310621242485, 22.03206412825651, 22.511022044088175, 22.98997995991984, 23.468937875751504, 23.947895791583168, 24.42685370741483, 24.905811623246493, 25.384769539078157, 25.86372745490982, 26.34268537074148, 26.821643286573146, 27.30060120240481, 27.779559118236474, 28.258517034068138, 28.7374749498998, 29.216432865731463, 29.695390781563127, 30.17434869739479, 30.65330661322645, 31.132264529058116, 31.61122244488978, 32.09018036072144, 32.569138276553105, 33.04809619238477, 33.52705410821643, 34.0060120240481, 34.48496993987976, 34.963927855711425, 35.44288577154309, 35.921843687374746, 36.40080160320641, 36.879759519038075, 37.35871743486974, 37.8376753507014, 38.31663326653307, 38.79559118236473, 39.274549098196395, 39.75350701402806, 40.23246492985972, 40.71142284569138, 41.190380761523045, 41.66933867735471, 42.14829659318637, 42.62725450901804, 43.1062124248497, 43.585170340681366, 44.06412825651302, 44.54308617234469, 45.02204408817635, 45.501002004008015, 45.97995991983968, 46.45891783567134, 46.93787575150301, 47.41683366733467, 47.895791583166336, 48.37474949899799, 48.85370741482966, 49.33266533066132, 49.811623246492985, 50.29058116232465, 50.76953907815631, 51.24849699398798, 51.72745490981964, 52.206412825651306, 52.68537074148296, 53.16432865731463, 53.64328657314629, 54.122244488977955, 54.60120240480962, 55.08016032064128, 55.55911823647295, 56.03807615230461, 56.517034068136276, 56.99599198396793, 57.4749498997996, 57.95390781563126, 58.432865731462925, 58.91182364729459, 59.390781563126254, 59.86973947895792, 60.34869739478958, 60.82765531062124, 61.3066132264529, 61.78557114228457, 62.26452905811623, 62.743486973947896, 63.22244488977956, 63.701402805611224, 64.18036072144288, 64.65931863727455, 65.13827655310621, 65.61723446893788, 66.09619238476954, 66.57515030060121, 67.05410821643287, 67.53306613226452, 68.0120240480962, 68.49098196392785, 68.96993987975952, 69.44889779559118, 69.92785571142285, 70.40681362725451, 70.88577154308618, 71.36472945891784, 71.84368737474949, 72.32264529058116, 72.80160320641282, 73.28056112224449, 73.75951903807615, 74.23847695390782, 74.71743486973948, 75.19639278557115, 75.6753507014028, 76.15430861723446, 76.63326653306613, 77.11222444889779, 77.59118236472946, 78.07014028056112, 78.54909819639279, 79.02805611222445, 79.50701402805612, 79.98597194388778, 80.46492985971943, 80.9438877755511, 81.42284569138276, 81.90180360721443, 82.38076152304609, 82.85971943887776, 83.33867735470942, 83.81763527054109, 84.29659318637275, 84.7755511022044, 85.25450901803607, 85.73346693386773, 86.2124248496994, 86.69138276553106, 87.17034068136273, 87.64929859719439, 88.12825651302605, 88.60721442885772, 89.08617234468937, 89.56513026052104, 90.0440881763527, 90.52304
