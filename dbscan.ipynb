# %%
import pandas as pd
from pathlib import Path
import numpy as np
from sklearn.cluster import DBSCAN
from utils import *

# %%
df = pd.read_pickle("data/flickr_data_with_features.pkl")

with open("data/tags_to_delete.txt", "r") as f:
    tags_to_delete = set(line.strip() for line in f)

# %%
YEAR = "all"
DISTANCE_METERS = 25
MIN_SAMPLES = 250
ONLY_SIMILAR_YEARS = True

sample = None
if YEAR == "all":
    sample = df.copy()
else:
    sample = df[df["date_taken"].dt.year == YEAR].copy()

if ONLY_SIMILAR_YEARS:
    sample = sample[sample["similar_year"] == 1]

coords = sample[["lat", "long"]].values

EARTH_RADIUS = 6371.0  # in km

clustering = DBSCAN(eps=DISTANCE_METERS / (EARTH_RADIUS * 1000), min_samples=MIN_SAMPLES, metric="haversine", algorithm="brute").fit(
    np.radians(coords)
)
sample["cluster"] = clustering.labels_

n_clusters = len(set(clustering.labels_)) - (1 if -1 in clustering.labels_ else 0)
n_noise = list(clustering.labels_).count(-1)

print(f"Number of clusters: {n_clusters}")
print(f"Number of noise points: {n_noise}")
print(f"\nCluster distribution:")
print(sample["cluster"].value_counts().sort_index())
# Out:
# Number of clusters: 68
# Number of noise points: 95516
#
# Cluster distribution:
# cluster
# -1     95516
#  0      7115
#  1      5654
#  2     14711
#  3       332
#        ...
#  63      769
#  64      190
#  65      269
#  66     1208
#  67      498
# Name: count, Length: 69, dtype: int64

# %%
# Get top N tags for each cluster
N_TOP_TAGS = 5  # Change this number as needed

cluster_top_tags = get_cluster_top_tags(sample, tags_to_delete, N_TOP_TAGS)
print(f"\nTop {N_TOP_TAGS} tags per cluster:")
for cluster_id in sorted(cluster_top_tags.keys()):
    print(f"Cluster {cluster_id}: {', '.join(cluster_top_tags[cluster_id])}")
# Out:
# Top 5 tags per cluster:
# Cluster 0: fourvière, basilique, church, rhône, fourviere
# Cluster 1: terreaux, placedesterreaux, muséedesbeauxartsdelyon, museum, place
# Cluster 2: demeureduchaos, abodeofchaos, thierryehrmann, alchemy, prophecy
# Cluster 3: vieuxlyon, musée, histoire, historique, architequture
# Cluster 4: bellecour, placebellecour, place, fêtedeslumières, places
# Cluster 5: square, opéra, fêtedeslumières, foursquare:venue=5148ec5ce4b0c012d308cb24, opera
# Cluster 6: vieuxlyon, square, placeduchange, rhône, unesco
# Cluster 7: vieuxlyon, rhône, cathédrale, saintjean, musée
# Cluster 8: rhône, night, river, nuit, jossaris
# Cluster 9: théâtredescélestins, fêtedeslumières, rhône, parking, architecture
# Cluster 10: jacobins, fontaine, placedesjacobins, fêtedeslumières, rhône
# Cluster 11: fêtedeslumières, lumières, placedelarépublique, rhône, illuminations
# Cluster 12: croixrousse, streetart, paper, wheatpaste, wheatpaper
# Cluster 13: bridge, saône, pont, saxophone, les
# Cluster 14: square, foursquare:venue=51472debe4b0c11f88609137, rise, foursquare:venue=515af769e4b05395d69ae1b2, xproii
# Cluster 15: nuit, saône, river, bridge, night
# Cluster 16: church, rhône, fêtedeslumières, nizier, frança
# Cluster 17: concert, transbordeur, music, metal, arnal
# Cluster 18: rhône, renaudcamus, masterpal, silver, gold
# Cluster 19: croixrousse, streetart, paper, wheatpaste, wheatpaper
# Cluster 20: artcontemporain, biennaledelyon, sucrière, confluence, lasucrière
# Cluster 21: mac, artcontemporain, musée, maclyon, art
# Cluster 22: theatre, fourviere, nuits, fourvière, romain
# Cluster 23: lumière, institutlumière, muséelumière, museum, 里昂
# Cluster 24: architectureromane, tentation, et, clocher, eve
# Cluster 25: norbert, cellier, norbertcellier, aquarium, poisson
# Cluster 26: croixrousse, streetart, paper, wheatpaper, wheatpaste
# Cluster 27: intérieur, chat, geotagged, noir, blanc
# Cluster 28: concert, metal, arnalphotography, arnallephotography, arnaudbouvard
# Cluster 29: bellecour, square, frança, street, mand
# Cluster 30: ilford400, lumiere, ballon, nuit, philippekling
# Cluster 31: bmx, skatepark, bergesdurhône, berges, guillotière
# Cluster 32: abtra, mai, loykrathong, nong, craponne
# Cluster 33: palaisdejustice, rhône, night, statue, nuit
# Cluster 34: passages, muséedesconfluences, mdc, photographie, patrickageneau
# Cluster 35: internetdesobjets, iot, sido, conférence, citéinternationaledelyon
# Cluster 36: insa, cross, 24h, orgas, uploaded:by=flickrmobile
# Cluster 37: mural, fresco, rhone, лион, wall
# Cluster 38: vieuxlyon, square, traboule, foursquare:venue=4b24e320f964a520546a24e3, oldlyon
# Cluster 39: top14, accréditation, lou, gerland, stadetoulousain
# Cluster 40: concert, ninkasikao, pentax, livepic, capturedalive
# Cluster 41:
# Cluster 42: bjd, dress, doll, ldoll, festival
# Cluster 43: concert, music, depechemode, davegahan, martingore
# Cluster 44: square, foursquare:venue=4be26f00b02ec9b6a1004dc0, rise, amaro, xproii
# Cluster 45: streetart, croixrousse, paper, wheatpaper, wheatpaste
# Cluster 46: fêtedeslumières, night, nuit, saône, festivaloflights
# Cluster 47: library, ifla, wlic, eblida, uploaded:by=flickrmobile
# Cluster 48:
# Cluster 49: musée, confluences, muséedesconfluences, confluence, museum
# Cluster 50: square, foursquare:venue=2664681, fêtedeslumières, streetart, lumières
# Cluster 51: square, foursquare:venue=4fe864b7e4b05b60faf6704b, rise, xproii, foursquare:venue=4e0462c82271233b767cec75
# Cluster 52: streetart, croixrousse, paper, wheatpaste, wheatpaper
# Cluster 53: boardgame, j2s, sunset, nuages, tangledfx
# Cluster 54: square, foursquare:venue=4be26f00b02ec9b6a1004dc0, xproii, rise, hudson
# Cluster 55: barrelracing, reining, wildfieldsphotography, show, jumping
# Cluster 56: studio, kaftan, caftan, kaftane, d2xs
# Cluster 57: guillotiere, coworking, mutualisation, locauxmotiv, makerparty
# Cluster 58: japan, touch, convention, decembre, japantouch
# Cluster 59: athlétisme, handisport, ipca, mondiaux, parilly
# Cluster 60: confluence, rhône, rouge, lego, f1
# Cluster 61: unicef, ong, comitérhône, unicefrhône, nepal
# Cluster 62: stade, ol, art, streetart, décinescharpieu
# Cluster 63: interurbain, car, autocar, autocarexpo, tourisme
# Cluster 64: cci, rhône, palaisdelabourse, square, architecture
# Cluster 65: forumled, conferencesexpo, citéinternationale, architecture, renzopiano
# Cluster 66: cosplay, japactu, japactuinfo, japantouch, cosplayjapactu
# Cluster 67: norbert, cellier, sauvagie, tassin, norbertcellier

# %%
save_dir = Path("./data/dbscan/")
save_dir.mkdir(parents=True, exist_ok=True)
create_cluster_map(sample=sample, cluster_top_tags=cluster_top_tags, year=YEAR, show_noise=False, show_points=False, save_dir=save_dir)
# Out:
# Cluster map saved to data/dbscan/all_clusters_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7344f23bfa9fa25902b3ce04c4c05c1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7344f23bfa9fa25902b3ce04c4c05c1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7344f23bfa9fa25902b3ce04c4c05c1a = L.map(
#                 &quot;map_7344f23bfa9fa25902b3ce04c4c05c1a&quot;,
#                 {
#                     center: [45.7615, 4.83],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37225a62dbbd97ae0804817e587dd37d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer